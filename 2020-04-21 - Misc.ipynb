# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version 0.0.3

# %%
t=linspace(1900,2000,101)
T=10+(t-1900)*.5 + 5*rand(len(t))

# %%
plot(t,T,'-o')

# %%
polyfit(t-1950,T,1)
# Out:
# array([ 0.49781628, 37.45926619])

# %%
polyfit(t,T,1)
# Out:
# array([ 4.97816280e-01, -9.33282479e+02])
