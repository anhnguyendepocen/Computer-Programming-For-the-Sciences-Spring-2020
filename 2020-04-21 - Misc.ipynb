# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version 0.0.3

# %%
t=linspace(1900,2000,101)
T=10+(t-1900)*.5 + 5*rand(len(t))

# %%
plot(t,T,'-o')

# %%
polyfit(t-1950,T,1)
# Out:
# array([ 0.49781628, 37.45926619])

# %%
polyfit(t,T,1)
# Out:
# array([ 4.97816280e-01, -9.33282479e+02])

# %%
from pyndamics import *
# Out:
# pyndamics version  0.0.10

# %%
t=linspace(0,10,100)
S=sin(t*3)
plot(t,S)

# %%
class InterpData(object):
    
    def __init__(self,x,y,name):
        self.x=x
        self.y=y
        self.__name__=name
        
    def __call__(self,x):
        from numpy import interp
        y=interp(x,self.x,self.y)
        return y

t=linspace(0,10,100)  # made up data, you can use the real thing
S=sin(t*3)

F=InterpData(t,S,'F')

# %%
sim=Simulation()
sim.add("v'=F(t)/m",0,plot=True)
sim.add("x'=v",0,plot=True)
sim.params(m=1)
sim.functions(F)
sim.run(0,10)

# %%
dir(sim)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add',
#  'add_data',
#  'add_system',
#  'assignments',
#  'compare',
#  'components',
#  'copy',
#  'data_delay',
#  'delay',
#  'equations',
#  'extra',
#  'figsize',
#  'figures',
#  'func',
#  'functions',
#  'get_component',
#  'inflow',
#  'initial_value',
#  'initial_values',
#  'initialized',
#  'interpolate',
#  'make_func',
#  'maximum_data_t',
#  'maximum_t',
#  'method',
#  'mse',
#  'myfunctions',
#  'myparams',
#  'noplots',
#  'omit',
#  'original_params',
#  'outflow',
#  'params',
#  'plot_style',
#  'post_process',
#  'repeat',
#  'run',
#  'run_fast',
#  'show',
#  'slider',
#  'stock',
#  'system_params',
#  'use_delays',
#  'use_func',
#  'vec2str',
#  'verbose']

# %%
sim.functions?
# Out:
# Signature: sim.functions(*args, **kwargs)
# Docstring: <no docstring>
# File:      ~/opt/anaconda3/lib/python3.7/site-packages/pyndamics/simulation.py
# Type:      method
