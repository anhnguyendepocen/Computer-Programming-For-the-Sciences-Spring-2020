# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version 0.0.3

# %%
filename='data/crichton/berkeley.csv'
data=pd.read_csv(filename)

x=array(data['YEAR'])
y=array(data['metANN'])
y[y==999.9]=nan


model=ols('y ~ x', data={'y':y,'x':x})
results=model.fit()



xx=linspace(min(x)-10,max(x)+10,20)
yy=results.predict({'x':xx})

m=results.params['x']
mσ=results.bse['x']

b=results.params['Intercept']

plot(x,y,'-o')
ylabel('Temperature [C]')
title(filename+" : y=%.3g (+/- %.4g) x + %.3g" % (m,mσ,b))
plot(xx,yy,'b-')

# %%
filename='data/crichton/pasadena.csv'
data=pd.read_csv(filename)

x=array(data['YEAR'])
y=array(data['metANN'])
y[y==999.9]=nan


model=ols('y ~ x', data={'y':y,'x':x})
results=model.fit()



xx=linspace(min(x)-10,max(x)+10,20)
yy=results.predict({'x':xx})

m=results.params['x']
mσ=results.bse['x']

b=results.params['Intercept']

plot(x,y,'-o')
ylabel('Temperature [C]')
title(filename+" : y=%.3g (+/- %.4g) x + %.3g" % (m,mσ,b))
plot(xx,yy,'b-')

# %%
for filename in ['data/crichton/berkeley.csv','data/crichton/pasadena.csv']:
    data=pd.read_csv(filename)

    x=array(data['YEAR'])
    y=array(data['metANN'])
    y[y==999.9]=nan


    model=ols('y ~ x', data={'y':y,'x':x})
    results=model.fit()



    xx=linspace(min(x)-10,max(x)+10,20)
    yy=results.predict({'x':xx})

    m=results.params['x']
    mσ=results.bse['x']

    b=results.params['Intercept']

    figure()
    plot(x,y,'-o')
    ylabel('Temperature [C]')
    title(filename+" : y=%.3g (+/- %.4g) x + %.3g" % (m,mσ,b))
    plot(xx,yy,'b-')

# %%
from glob import glob

filenames=glob('data/crichton/*.csv')
filenames
# Out:
# ['data/crichton/pasadena.csv', 'data/crichton/berkeley.csv']

# %%
filenames=glob('data/crichton/b*.csv')
filenames
# Out:
# ['data/crichton/berkeley.csv']

# %%
filenames=glob('data/crichton/*.csv')

for filename in filenames:
    data=pd.read_csv(filename)

    x=array(data['YEAR'])
    y=array(data['metANN'])
    y[y==999.9]=nan


    model=ols('y ~ x', data={'y':y,'x':x})
    results=model.fit()



    xx=linspace(min(x)-10,max(x)+10,20)
    yy=results.predict({'x':xx})

    m=results.params['x']
    mσ=results.bse['x']

    b=results.params['Intercept']

    figure()
    plot(x,y,'-o')
    ylabel('Temperature [C]')
    title(filename+" : y=%.3g (+/- %.4g) x + %.3g" % (m,mσ,b))
    plot(xx,yy,'b-')

# %%
filenames=glob('data/crichton/*.csv')

storage=Storage()

for filename in filenames:
    data=pd.read_csv(filename)

    x=array(data['YEAR'])
    y=array(data['metANN'])
    y[y==999.9]=nan


    model=ols('y ~ x', data={'y':y,'x':x})
    results=model.fit()



    xx=linspace(min(x)-10,max(x)+10,20)
    yy=results.predict({'x':xx})

    m=results.params['x']
    mσ=results.bse['x']

    b=results.params['Intercept']

    
    storage+=m,mσ
#     figure()
#     plot(x,y,'-o')
#     ylabel('Temperature [C]')
#     title(filename+" : y=%.3g (+/- %.4g) x + %.3g" % (m,mσ,b))
#     plot(xx,yy,'b-')

m,mσ=array(storage)

# %%
m
# Out:
# array([0.0115909 , 0.00481475])

# %%
mσ
# Out:
# array([0.0018094 , 0.00125025])
