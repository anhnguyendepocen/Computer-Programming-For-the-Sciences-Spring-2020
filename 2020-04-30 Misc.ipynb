# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version 0.0.3

# %%
x=linspace(-10,10,100)

for i in range(5):
    
    b=0
    m=randn()
    y=m*x+b + rand(len(x))
    
    plot(x,y)

# %%
x=linspace(-10,10,100)

for i in range(5):
    
    b=0
    m=randn()
    y=m*x+b + rand(len(x))
    
    plot(x,y,'b-')

# %%
x=linspace(-10,10,100)

for i in range(5):
    
    b=0
    m=randn()
    y=m*x+b + rand(len(x))
    
    figure()
    plot(x,y,'b-')
