# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version 0.0.3

# %%
data=pd.read_excel('data/new_info.xlsx')
data
# Out:
#      Unnamed: 0                Station         m  brightness  longitude  \
# 0             0                   SAVE  0.024952        45.0    11.8667
# 1             1     SHARJAH_INTER_AIRP -0.001723        39.0    55.5170
# 2             2    RAS_AL_KHAIMAH_INTE  0.018616        17.0    55.9330
# 3             3             DUBAI_INTL  0.012132       104.0    55.3640
# 4             4   ABU_DHABI_BATEEN_AIR  0.037361       114.0    54.4700
# ..          ...                    ...       ...         ...        ...
# 152         152          VILLA_DOLORES  0.009966        15.0   -65.1460
# 153         153   CORDOBA_OBSERVATORIO  0.017682        94.0   -64.1830
# 154         154     PILAR_OBSERVATORIO  0.015549        16.0   -63.8830
# 155         155  COMODORO_PIERRESTEGUI  0.018198         0.0   -57.9970
# 156         156             SAN_MARTIN -0.010294         0.0   -68.4170
#
#      latitude  elevation
# 0     57.7667       18.0
# 1     25.3330       34.0
# 2     25.6170       31.0
# 3     25.2550       10.4
# 4     24.4300        3.0
# ..        ...        ...
# 152  -31.9450      583.7
# 153  -31.4000      426.0
# 154  -31.6670      338.0
# 155  -31.2970       34.1
# 156  -33.0830      653.0
#
# [157 rows x 7 columns]

# %%
model=ols('m ~ brightness',data=data)
results=model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      m   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                  0.004639
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.946
# Time:                        14:48:58   Log-Likelihood:                 295.09
# No. Observations:                 157   AIC:                            -586.2
# Df Residuals:                     155   BIC:                            -580.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0114      0.004      3.182      0.002       0.004       0.018
# brightness -8.661e-06      0.000     -0.068      0.946      -0.000       0.000
# ==============================================================================
# Omnibus:                       62.942   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              306.834
# Skew:                          -1.380   Prob(JB):                     2.35e-67
# Kurtosis:                       9.268   Cond. No.                         33.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results.params
# Out:
# Intercept     0.011378
# brightness   -0.000009
# dtype: float64

# %%
model=ols('m ~ brightness + longitude + latitude',data=data)
results=model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      m   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.249
# Date:                Thu, 23 Apr 2020   Prob (F-statistic):              0.294
# Time:                        14:49:42   Log-Likelihood:                 296.99
# No. Observations:                 157   AIC:                            -586.0
# Df Residuals:                     153   BIC:                            -573.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0089      0.005      1.866      0.064      -0.001       0.018
# brightness  9.069e-06      0.000      0.072      0.943      -0.000       0.000
# longitude     -0.0002      0.000     -1.386      0.168      -0.000    6.82e-05
# latitude     4.63e-05      0.000      0.287      0.775      -0.000       0.000
# ==============================================================================
# Omnibus:                       56.381   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              277.926
# Skew:                          -1.202   Prob(JB):                     4.46e-61
# Kurtosis:                       9.059   Cond. No.                         79.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
